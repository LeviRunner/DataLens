# %% [markdown]
# # 01 — Exploração em SQL (Fase 1)
#
# Ideia (sem código): rascunho da Fase 1. Anotar 5 perguntas de negócio sobre os dados de finanças e respondê-las apenas com SQL (SELECT, GROUP BY, JOIN, window functions). Vira material de portfólio.
