# %% [markdown]
# # Exploração em SQL (perguntas de negócio de finanças)
#
# Anotar 5 perguntas de negócio sobre os dados de finanças e respondê-las apenas com SQL (SELECT, GROUP BY, JOIN, window functions).
#
# # 1. Qual ativo apresentou a maior volatilidade (desvio padrão dos retornos diários) no período?
#
# Query: SQL_exploracao_1.sql
# - ![SQL_1.png](attachment:SQL_1.png)
#
# # 2. Qual é o volume financeiro médio diário por classe de ativo?
#
# Query: SQL_exploracao_2.sql
# - ![SQL_2.png](attachment:SQL_2.png)
#
# # 3. Como está a Média Móvel de 30 dias (SMA) em relação ao preço de fechamento atual?
#
# Query: SQL_exploracao_3.sql
# - ![SQL_3.png](attachment:SQL_3.png)
#
# # 4. Qual foi o retorno acumulado de cada ativo no período total da base?
#
# Query: SQL_exploracao_4.sql
# - ![SQL_4.png](attachment:SQL_4.png)
#
# # 5. Quais foram os dias de "Rompimento" (Volume 50% acima da média e fechamento positivo)?
#
# Query: SQL_exploracao_5.sql
# - ![SQL_5.png](attachment:SQL_5.png)
