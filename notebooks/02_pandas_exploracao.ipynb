# %% [markdown]
# # 02 — Exploração em pandas (Fase 3)
#
# Ideia (sem código): refazer a análise da Fase 1 usando pandas (DataFrame, filtro, groupby) para comparar SQL x Python e preparar o que vira o módulo de perfil.
